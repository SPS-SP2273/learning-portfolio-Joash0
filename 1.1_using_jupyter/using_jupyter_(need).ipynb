# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 Getting ready

# %% [markdown]
# # 2 Getting started with Jupyter

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ## 2.1 It is all about running cells

# %% [markdown]
# ## 2.2 A traditional start

# %% [markdown]
# # 3 All about Markdown

# %% [markdown]
# ## 3.1 Rendering Markdown cells

# %% [markdown]
# *hahaha* is in **italics**
#
# # Heading
#
# **Lmao**^[hahaha]

# %% [markdown]
# '''python
# print('Hello World')
# '''

# %% [markdown]
# | A | B | C |
# |:---|---:|---:|
# | a1  |a2  |a3   |
# |b1 2  |b2 3 |b3 4  |
# |c1 2  |c2 33 |c35   |

# %% [markdown]
# $x^2$

# %% [markdown]
# Use of $ is to insert math equation in it

# %% [markdown]
# $f(x)=x^2$
# $\int_{x=1}^{x=\infty} x^2 dx$

# %% [markdown]
# *lmao I love coding*

# %% [markdown]
# CH<sub>4</sub> (g) + 2O<sub>2</sub> (g) -> CO<sub>2</sub> (g) + H<sub>2</sub>O(l)

# %% [markdown]
# ```python
# print("Hello World")
# ```

# %% [markdown]
# [SPS Website SP2273](https://sps.nus.edu.sg/sp2273/)

# %% [markdown]
# ![]![image.png](attachment:image.png)

# %% [markdown]
# 1. Joash
# 1. Jimmy
# 1. Lmao

# %% [markdown]
# - Joash
# - Jimmy
# - Lmao

# %% [markdown]
# 1. Joash
#     1. Jimmy
#     1. Koopa
# 1. Kmao
#     1. Kpods
#     1. Kpoop
#     1. Jpop

# %% [markdown]
# $$
# x= \dfrac{-b \pm \sqrt{b^2-4ac}}{2a}
# $$

# %% [markdown]
# ## 3.2 Some basic syntax

# %% [markdown]
# ## 3.3 Headings

# %% [markdown]
# ## 3.4 Displaying Code

# %% [markdown]
# ## 3.5 Links

# %% [markdown]
# ## 3.6 Images

# %% [markdown]
# ## 3.7 Tables

# %% [markdown]
# ## 3.8 Lists

# %% [markdown]
# ## 3.9 Equations

# %% [markdown]
# ## Footnotes
