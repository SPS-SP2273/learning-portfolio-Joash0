# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %% [markdown]
# #### Exercise 1 (Tidying a collaboration)

# %% [markdown]
# #### Task 1

# %%
months = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

old_file_name = "oct-08_singapore.txt"

file_type = old_file_name.split(".")[-1]
remainder = old_file_name.split(".")[0]
month_day, city = remainder.split("_")   
month, day = month_day.split("-")       
month_num = months[month]
new_filename = f"{month_num}-{day}_{city}.{file_type}"

print(new_filename)
# Out:
# 10-08_singapore.txt

# %% [markdown]
# #### Task 2

# %%
def rename_my_file(old_file_name):
    file_type = old_file_name.split(".")[-1]
    remainder = old_file_name.split(".")[0]
    month_day, city = remainder.split("_")   
    month, day = month_day.split("-")       
    month_num = months[month]
    new_filename = f"{month_num}-{day}_{city}.{file_type}"
    return new_filename

print(rename_my_file(old_file_name))
# Out:
# 10-08_singapore.txt

# %% [markdown]
# #### Task 3

# %%
file_list = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

#do not need to redefined dictionaries and functions mentioned in earlier exercises

for i in range (10):
    old_file_name = file_list[i] 
    new_filename = rename_my_file(old_file_name)
    print(f'{old_file_name}---->{new_filename}')
# Out:
# oct-08_singapore.txt---->10-08_singapore.txt
# jul-10_cairo.txt---->07-10_cairo.txt
# may-15_dhaka.txt---->05-15_dhaka.txt
# may-13_cairo.txt---->05-13_cairo.txt
# oct-21_cairo.txt---->10-21_cairo.txt
# jan-10_singapore.txt---->01-10_singapore.txt
# jun-20_tokyo.txt---->06-20_tokyo.txt
# aug-06_jakarta.txt---->08-06_jakarta.txt
# dec-21_karachi.txt---->12-21_karachi.txt
# jan-01_tokyo.txt---->01-01_tokyo.txt

# %% [markdown]
# #### Task 4

# %%
import glob, os

months = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

# Old Method:
#def rename_my_file(old_file_name):
   # try:
        #file_type = old_file_name.split(".")[-1] # define .txt
        #remainder = old_file_name.split(".")[0]
       # formated_old_file_name = remainder.split('\\')[-1] # remove os-collaboration-exercise-data
      #  month_day, city = formated_old_file_name.split("_")
     #   month, day = month_day.split("-")
    #    month_num = months[month]
   #     new_file_name = f"{month_num}-{day}-{city}.{file_type}"
  #      new_path = os.path.join('os-collaboration-exercise-data', new_file_name)
 #       print(os.rename(old_file_name, new_path)) 
#        return os.rename(old_file_name, new_path)
        # rename file name under function. If you place under 'try' block, you would cause new file names to be renamed again under for loops, which causes errors.
       # Learning point: os.rename is a function that does not return any output. Thus, printing os.rename(old_file_name, new_path) would result in 'None' appearing.
#    except:
#        return old_file_name
# Learning point: No need to define function again that has already been defined earlier. Don't waste time
for i in glob.glob("os-collaboration-exercise-data/**/*.txt", recursive=True):
    try:
        formated_old_file_name = i.split('\\')[-1]
        new_file_name = rename_my_file(formated_old_file_name) # for every old file in the folder, the function was performed.
        new_path = os.path.join('os-collaboration-exercise-data', new_file_name)
        os.rename(i, new_path)
    except:
        pass

# %% [markdown]
# #### Task 5

# %%
cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

for city in cities:
    path = os.path.join('os-collaboration-exercise-data', city)
    print(f'Creating {path}')
    os.mkdir(path) # mkdir would actually create a folder seen on the left
# Out:
# Creating os-collaboration-exercise-data\Cairo
# Creating os-collaboration-exercise-data\Dhaka
# Creating os-collaboration-exercise-data\Jakarta
# Creating os-collaboration-exercise-data\Karachi
# Creating os-collaboration-exercise-data\Manila
# Creating os-collaboration-exercise-data\Melbourne
# Creating os-collaboration-exercise-data\Osaka
# Creating os-collaboration-exercise-data\Shanghai
# Creating os-collaboration-exercise-data\Singapore
# Creating os-collaboration-exercise-data\Tokyo

# %% [markdown]
# #### Task 6

# %%
import glob, shutil

for i in glob.glob("os-collaboration-exercise-data/**/*_cairo.txt", recursive=True): # goes into every folder
    shutil.copy(i, "os-collaboration-exercise-data\\Cairo")

# %% [markdown]
# #### Task 7

# %%
import glob, os, shutil
import numpy as np

cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

file_list = []
for city in cities:
    for file_name in glob.glob(f"os-collaboration-exercise-data/**/*_{city}.txt", recursive=True):
        formated_date_city = file_name.split("\\")[-1]
        file_list.append(formated_date_city)
print(file_list)

def finding_duplicate_file(file_name):
    file_np_array = np.array(file_list)
    formated_date_city = file_name.split("\\")[-1]
    mask = file_np_array == formated_date_city
    print(mask.sum())
    return mask.sum()

for city in cities:
    for i in glob.glob(f"os-collaboration-exercise-data/**/*_{city}.txt", recursive=True):
        try:
            folder_name = os.path.join("os-collaboration-exercise-data", city)
            shutil.move(i, folder_name)
        except:
            number = finding_duplicate_file(i)
            if number > 1:
                formated_date_city = i.split("\\")[-1]
                file_list.remove(formated_date_city)
                os.remove(i)
            else:
                pass

for item in glob.glob("**", recursive=True):
    print(item)
# FINALLY LAH I'M DONE :')
# Out:
# ['01-02_cairo.txt', '01-03_cairo.txt', '01-04_cairo.txt', '01-05_cairo.txt', '01-07_cairo.txt', '01-08_cairo.txt', '01-09_cairo.txt', '01-11_cairo.txt', '01-12_cairo.txt', '01-13_cairo.txt', '01-15_cairo.txt', '01-16_cairo.txt', '01-19_cairo.txt', '01-20_cairo.txt', '01-21_cairo.txt', '01-23_cairo.txt', '01-27_cairo.txt', '01-30_cairo.txt', '02-10_cairo.txt', '02-17_cairo.txt', '02-20_cairo.txt', '02-22_cairo.txt', '02-25_cairo.txt', '02-26_cairo.txt', '03-05_cairo.txt', '03-06_cairo.txt', '03-12_cairo.txt', '03-14_cairo.txt', '03-19_cairo.txt', '03-24_cairo.txt', '04-02_cairo.txt', '04-06_cairo.txt', '04-07_cairo.txt', '04-10_cairo.txt', '04-12_cairo.txt', '04-13_cairo.txt', '04-14_cairo.txt', '04-15_cairo.txt', '04-17_cairo.txt', '04-20_cairo.txt', '04-21_cairo.txt', '04-22_cairo.txt', '04-23_cairo.txt', '04-24_cairo.txt', '05-01_cairo.txt', '05-02_cairo.txt', '05-12_cairo.txt', '05-17_cairo.txt', '05-25_cairo.txt', '05-27_cairo.txt', '05-29_cairo.txt', '05-30_cairo.txt', '06-28_ca
# ...
