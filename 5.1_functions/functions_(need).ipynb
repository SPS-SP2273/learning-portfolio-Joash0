# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Functions (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 User-defined functions

# %% [markdown]
# ## 1.1 Named Functions

# %% [markdown]
# ### Named functions that return

# %%
# Your code here

# %% [markdown]
# ### Named functions that don’t return

# %%
# Your code here

# %% [markdown]
# ## 1.2 Anonymous functions

# %% [markdown]
# ## 1.3 Optional arguments

# %% [markdown]
# ## 1.4 The importance of functions?

# %%
import math
import random
import matplotlib.pyplot as plt

# y = mx + c

def my_line(m, c):
    x_values = [x for x in range(100)]
    y_values = [m*x + c + 50*random.random() for x in x_values]
    return x_values, y_values

x, y = my_line(3, 2)
plt.plot(x, y)

# %%
plt.plot((x, y))
# Out:
# [<matplotlib.lines.Line2D at 0x2155613d6d0>,
#  <matplotlib.lines.Line2D at 0x2155613d810>,
#  <matplotlib.lines.Line2D at 0x2155613d950>,
#  <matplotlib.lines.Line2D at 0x2155613da90>,
#  <matplotlib.lines.Line2D at 0x2155613dbd0>,
#  <matplotlib.lines.Line2D at 0x2155613dd10>,
#  <matplotlib.lines.Line2D at 0x2155613de50>,
#  <matplotlib.lines.Line2D at 0x2155613df90>,
#  <matplotlib.lines.Line2D at 0x2155613e0d0>,
#  <matplotlib.lines.Line2D at 0x2155613e210>,
#  <matplotlib.lines.Line2D at 0x2155613e350>,
#  <matplotlib.lines.Line2D at 0x2155613e490>,
#  <matplotlib.lines.Line2D at 0x2155613e5d0>,
#  <matplotlib.lines.Line2D at 0x2155613e710>,
#  <matplotlib.lines.Line2D at 0x2155613e850>,
#  <matplotlib.lines.Line2D at 0x2155613e990>,
#  <matplotlib.lines.Line2D at 0x2155613ead0>,
#  <matplotlib.lines.Line2D at 0x2155613ec10>,
#  <matplotlib.lines.Line2D at 0x2155613ed50>,
#  <matplotlib.lines.Line2D at 0x2155613ee90>,
#  <matplotlib.lines.Line2D at 0x2155613efd0>,
#  <matplotlib.lines.Line2D at 0x2155613f110>,
#  <matplotlib.lines.Line2D at 0x2155613f250>,
#  <matplotlib.lines.Line2D at 0x2155613f390>,
#  <matplotlib.lines.Line2D at 0x2155613f4d0>,
#  <matplotlib.lines.Line2D at 0x2155613f610>,
#  <matplotlib.lines.Line2D at 0x2155613f750>,
#  <matplotlib.lines.Line2D at 0x2155613f890>,
#  <matplotlib.lines.Line2D at 0x2155613f9d0>,
#  <matplotlib.lines.Line2D at 0x2155613fb10>,
#  <matplotlib.lines.Line2D at 0x2155613fc50>,
#  <matplotlib.lines.Line2D at 0x2155613fd90>,
#  <matplotlib.lines.Line2D at 0x2155613fed0>,
#  <matplotlib.lines.Line2D at 0x215562a0190>,
#  <matplotlib.lines.Line2D at 0x215562a02d0>,
#  <matplotlib.lines.Line2D at 0x215562a0410>,
#  <matplotlib.lines.Line2D at 0x215562a0550>,
#  <matplotlib.lines.Line2D at 0x215562a0690>,
#  <matplotlib.lines.Line2D at 0x215562a07d0>,
#  <matplotlib.lines.Line2D at 0x215562a0910>,
#  <matplotlib.lines.Line2D at 0x215562a0a50>,
#  <matplotlib.lines.Line2D at 0x215562a0050>,
#  <matplotlib.lines.Line2D at 0x215562a0b90>,
#  <matplotlib.lines.Line2D at 0x215562a0cd0>,
#  <matplotlib.lines.Line2D at 0x215562a0e10>,
#  <matplotlib.lines.Line2D at 0x215562a0f50>,
#  <matplotlib.lines.Line2D at 0x215562a1090>,
#  <matplotlib.lines.Line2D at 0x215562a11d0>,
#  <matplotlib.lines.Line2D at 0x215562a1310>,
#  <matplotlib.lines.Line2D at 0x215562a1450>,
#  <matplotlib.lines.Line2D at 0x215562a1590>,
#  <matplotlib.lines.Line2D at 0x215562a16d0>,
#  <matplotlib.lines.Line2D at 0x215562a1810>,
#  <matplotlib.lines.Line2D at 0x215562a1950>,
#  <matplotlib.lines.Line2D at 0x215562a1a90>,
#  <matplotlib.lines.Line2D at 0x215562a1bd0>,
#  <matplotlib.lines.Line2D at 0x215562a1d10>,
#  <matplotlib.lines.Line2D at 0x215562a1e50>,
#  <matplotlib.lines.Line2D at 0x215562a1f90>,
#  <matplotlib.lines.Line2D at 0x215562a20d0>,
#  <matplotlib.lines.Line2D at 0x215562a2210>,
#  <matplotlib.lines.Line2D at 0x215562a2350>,
#  <matplotlib.lines.Line2D at 0x215562a2490>,
#  <matplotlib.lines.Line2D at 0x215562a25d0>,
#  <matplotlib.lines.Line2D at 0x215562a2710>,
#  <matplotlib.lines.Line2D at 0x215562a2850>,
#  <matplotlib.lines.Line2D at 0x215562a2990>,
#  <matplotlib.lines.Line2D at 0x215562a2ad0>,
#  <matplotlib.lines.Line2D at 0x215562a2c10>,
#  <matplotlib.lines.Line2D at 0x215562a2d50>,
#  <matplotlib.lines.Line2D at 0x215562a2e90>,
#  <matplotlib.lines.Line2D at 0x215562a2fd0>,
#  <matplotlib.lines.Line2D at 0x215562a3110>,
#  <matplotlib.lines.Line2D at 0x215562a3250>,
#  <matplotlib.lines.Line2D at 0x215562a3390>,
#  <matplotlib.lines.Line2D at 0x215562a34d0>,
#  <matplotlib.lines.Line2D at 0x215562a3610>,
#  <matplotlib.lines.Line2D at 0x215562a3750>,
#  <matplotlib.lines.Line2D at 0x215562a3890>,
#  <matplotlib.lines.Line2D at 0x215562a39d0>,
#  <matplotlib.lines.Line2D at 0x215562a3b10>,
#  <matplotlib.lines.Line2D at 0x215562a3c50>,
#  <matplotlib.lines.Line2D at 0x215562a3d90>,
#  <matplotlib.lines.Line2D at 0x215562a3ed0>,
#  <matplotlib.lines.Line2D at 0x215562c4050>,
#  <matplotlib.lines.Line2D at 0x215562c4190>,
#  <matplotlib.lines.Line2D at 0x215562c42d0>,
#  <matplotlib.lines.Line2D at 0x215562c4410>,
#  <matplotlib.lines.Line2D at 0x215562c4550>,
#  <matplotlib.lines.Line2D at 0x215562c4690>,
#  <matplotlib.lines.Line2D at 0x215562c47d0>,
#  <matplotlib.lines.Line2D at 0x215562c4910>,
#  <matplotlib.lines.Line2D at 0x215562c4a50>,
#  <matplotlib.lines.Line2D at 0x215562c4b90>,
#  <matplotlib.lines.Line2D at 0x215562c4cd0>,
#  <matplotlib.lines.Line2D at 0x215562c4e10>,
#  <matplotlib.lines.Line2D at 0x215562c4f50>,
#  <matplotlib.lines.Line2D at 0x215562c5090>,
#  <matplotlib.lines.Line2D at 0x215562c51d0>,
#  <matplotlib.lines.Line2D at 0x215562c5310>]

# %% [markdown]
# ### An argument for functions

# %%
# Your code here

# %% [markdown]
# ### A word of caution

# %%
# Your code here

# %%
import numpy as np
def my_line_np(m, c):
    x_values = np.linspace(0, 10, 5) # 0, 2, 4, 6, 8
    y_values = m*x_values + c+ 5*np.random.random()
    return x_values, y_values

def write_data(m, c):
    x_values = np.linspace(0, 10, 5)
    y_values = m*x_values + c+ 5*np.random.random()
    np.savetxt(f'hahaha_{m=}_{c=}=txt', (x_values, y_values))

Z = my_line_np(m=500, c=100)

np.arange(0, 11, 5) #0, 5, 10
# Out:
# array([ 0,  5, 10])

# %%
plt.plot(Z)
# Out:
# [<matplotlib.lines.Line2D at 0x21555d0e490>,
#  <matplotlib.lines.Line2D at 0x21555d0e5d0>,
#  <matplotlib.lines.Line2D at 0x21555d0e710>,
#  <matplotlib.lines.Line2D at 0x21555d0e850>,
#  <matplotlib.lines.Line2D at 0x21555d0e990>]
